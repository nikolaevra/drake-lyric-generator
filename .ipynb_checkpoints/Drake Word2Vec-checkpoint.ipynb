# %%
import numpy as np
import pandas as pd

# %%
# !ls
# Out:
# drake-songs.csv  Drake Word2Vec.ipynb  scrapper.py

# %%
songs = pd.read_csv('drake-songs.csv')

# %%
songs.head()
# Out:
#               song        album  \
# 0       successful  so-far-gone
# 1  best-i-ever-had  so-far-gone
# 2           uptown  so-far-gone
# 3      im-going-in  so-far-gone
# 4         the-calm  so-far-gone
#
#                                               lyrics
# 0  Money, money, cars, cars Clothes, clothes, the...
# 1  You know alot of girls be Thinkin' my songs ar...
# 2  Yeah.. Uh huhhhUh, Hardly Home But Always Repp...
# 3  Hello mothafucka, hey hi how ya durrn'? It's W...
# 4  Uh, I'm just so far gone, october's own, Pleas...

# %%
songs.dtypes
# Out:
# song      object
# album     object
# lyrics    object
# dtype: object

# %%
import re
from unidecode import unidecode

words = []

for index, row in songs['lyrics'].iteritems():
    row = str(row).lower()
    new_words = re.findall(r"\b[a-z']+[a-z']+\b", unidecode(row))
    words = words + new_words
    print('processing: {} -> {}. {} new words'.format(index, row[:20], len(new_words)))
# Out:
# processing: 0 -> money, money, cars, . 703 new words
# processing: 1 -> you know alot of gir. 735 new words
# processing: 2 -> yeah.. uh huhhhuh, h. 961 new words
# processing: 3 -> hello mothafucka, he. 548 new words
# processing: 4 -> uh, i'm just so far . 552 new words
# processing: 5 -> this is why i do thi. 630 new words
# processing: 6 -> money just changed e. 589 new words
# processing: 7 -> i know way too many . 379 new words
# processing: 8 -> i know way too many . 549 new words
# processing: 9 -> how did i end up rig. 504 new words
# processing: 10 -> kush rolled, glass f. 395 new words
# processing: 11 -> go, go 'head go, go,. 853 new words
# processing: 12 -> these girls ain't go. 687 new words
# processing: 13 -> let me know, let me . 548 new words
# processing: 14 -> i've been up for 4 d. 637 new words
# processing: 15 -> i said tell me what'. 762 new words
# processing: 16 -> i'm more than just a. 256 new words
# processing: 17 -> you could thank me n. 738 new words
# processing: 18 -> how i'm feeling, it . 607 new words
# processing: 19 -> i can see it in your. 393 new words
# processing: 20 -> i might be too strun. 451 new words
# processing: 21 -> take your nose off m. 331 new words
# processing: 22 -> i know you've been h. 436 new words
# processing: 23 -> hello? yeah, i just . 522 new words
# processing: 24 -> bridge over troubled. 602 new words
# processing: 25 -> yeah, never thoughts. 580 new words
# processing: 26 -> i like a woman with . 446 new words
# processing: 27 -> all we wanted was op. 688 new words
# processing: 28 -> when a good thing go. 341 new words
# processing: 29 -> people around you sh. 699 new words
# processing: 30 -> it's like '09 in you. 631 new words
# processing: 31 -> gotta do what i gott. 525 new words
# processing: 32 -> cash money shit cash. 522 new words
# processing: 33 -> i hate when, i hate . 663 new words
# processing: 34 -> i'm the fuckin man, . 711 new words
# processing: 35 -> comin' off the last . 716 new words
# processing: 36 -> somewhere between ps. 556 new words
# processing: 37 -> started... (zombie o. 445 new words
# processing: 38 -> it's yours it's your. 500 new words
# processing: 39 -> i just love when i'm. 482 new words
# processing: 40 -> worst mothafucka nev. 520 new words
# processing: 41 -> what's up? been a mi. 597 new words
# processing: 42 -> i got my eyes on you. 282 new words
# processing: 43 -> isn't it amazing how. 385 new words
# processing: 44 -> yeah yeah yeah yeah . 575 new words
# processing: 45 -> drop down, drop-drop. 498 new words
# processing: 46 -> don't think about it. 567 new words
# processing: 47 -> good god almighty, l. 888 new words
# processing: 48 -> when i pull up on a . 353 new words
# processing: 49 -> lickwood means rewin. 417 new words
# processing: 50 -> 10 bands, 50 bands 1. 414 new words
# processing: 51 -> wallets, wallets, wa. 426 new words
# processing: 52 -> envelopes coming in . 667 new words
# processing: 53 -> breathe through, rid. 210 new words
# processing: 54 -> rrrr tingi'll admit . 404 new words
# processing: 55 -> young nigga preach p. 334 new words
# processing: 56 -> been a minute since . 192 new words
# processing: 57 -> yeah, sound sound so. 718 new words
# processing: 58 -> boomin' out in south. 328 new words
# processing: 59 -> i got some shit for . 493 new words
# processing: 60 -> having conversations. 687 new words
# processing: 61 -> rock me real slowly . 377 new words
# processing: 62 -> yeah, oh you gotta l. 855 new words
# processing: 63 -> my dope in the bushe. 681 new words
# processing: 64 -> yea, i know we just . 528 new words
# processing: 65 -> hendrix ah, ah i wok. 484 new words
# processing: 66 -> i'm at a stage in my. 503 new words
# processing: 67 -> i wake up on a daily. 444 new words
# processing: 68 -> if anybody know i kn. 451 new words
# processing: 69 -> draped in all design. 425 new words
# processing: 70 -> yeah, know how night. 542 new words
# processing: 71 -> if young metro don't. 457 new words
# processing: 72 -> first i got married . 535 new words
# processing: 73 -> never thought i'd be. 673 new words
# processing: 74 -> it's a little chilly. 488 new words
# processing: 75 -> yeah, for the dogs d. 360 new words
# processing: 76 -> what these bitches w. 558 new words
# processing: 77 -> i should be downtown. 292 new words
# processing: 78 -> why you live off of . 500 new words
# processing: 79 -> one of them ones rig. 713 new words
# processing: 80 -> yeah, i get it i get. 652 new words
# processing: 81 -> it's about us right . 253 new words
# processing: 82 -> check, 1-2, 1-2, bit. 296 new words
# processing: 83 -> doin' well dog yeah,. 380 new words
# processing: 84 -> right, my yiy just c. 378 new words
# processing: 85 -> baby, i like your st. 348 new words
# processing: 86 -> yeah, yeah yeah, yea. 567 new words
# processing: 87 -> breaking news my nig. 583 new words
# processing: 88 -> dropped outta school. 399 new words
# processing: 89 -> oh yeah, yeah, yeah . 496 new words
# processing: 90 -> dedicate, i dedicate. 280 new words
# processing: 91 -> question is will i e. 562 new words
# processing: 92 -> you used to call me . 411 new words
# processing: 93 -> is it the strength o. 535 new words
# processing: 94 -> really? yeah (six!) . 396 new words
# processing: 95 -> hold on, hold on fuc. 213 new words
# processing: 96 -> hello i've been hurt. 163 new words
# processing: 97 -> i cannot tell who is. 267 new words
# processing: 98 -> unruly, unruly, madd. 324 new words
# processing: 99 -> i'm runnin', but can. 171 new words
# processing: 100 -> hermès link, ice-blu. 309 new words
# processing: 101 -> murda on the beat, s. 614 new words
# processing: 102 -> wrote this shit, jan. 807 new words
# processing: 103 -> you ever hear some s. 139 new words
# processing: 104 -> your heart is hard t. 303 new words
# processing: 105 -> ness on the beatyeah. 262 new words
# processing: 106 -> i don't care what so. 691 new words
# processing: 107 -> yeah, uh, man, fresh. 511 new words
# processing: 108 -> watch out for me, i'. 380 new words
# processing: 109 -> yeahaccording to my,. 438 new words
# processing: 110 -> yeah, yeahi've been . 432 new words
# processing: 111 -> yeah nigga, what you. 411 new words
# processing: 112 -> yeah, stylin' though. 598 new words
# processing: 113 -> [intro] yeah they wi. 323 new words
# processing: 114 -> [verse] diplomatic i. 593 new words

# %%
vocab = set(words)

word_to_index = {w: i for i, w in enumerate(vocab)}
index_to_word = {i: w for w, i in word_to_index.items()}
word_indices = [word_to_index[word] for word in vocab]
vocab_n = len(vocab)

# %%
ntk = [vocab_n]
X_indices_of_ones = np.array(word_indices + word_indices)
previous_word = ntk + word_indices[:-1]
next_word = word_indices[1:] + ntk
y_indices_of_ones = np.array(previous_word + next_word)

# %%
X = np.zeros((X_indices_of_ones.shape[0], vocab_n + 1))
X[np.arange(X.shape[0]), X_indices_of_ones] = 1

y = np.zeros((y_indices_of_ones.shape[0], vocab_n + 1))
y[np.arange(y.shape[0]), y_indices_of_ones] = 1

# %%
print(X.shape)
print(y.shape)
# Out:
# (11282, 5642)
# (11282, 5642)

# %%
batch_size = 10
divisible_size = 11280

X_b = X[:divisible_size, :].reshape(int(divisible_size / batch_size), batch_size, vocab_n + 1)
y_b = y[:divisible_size, :].reshape(int(divisible_size/batch_size), batch_size, vocab_n + 1)

# %%
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import Adam

encoding_size = 8

model = Sequential()
model.add(Dense(encoding_size, input_shape=(batch_size, vocab_n + 1), activation='relu'))
model.add(Dense(vocab_n + 1, activation='softmax'))

model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_92 (Dense)             (None, 10, 8)             45144
# _________________________________________________________________
# dense_93 (Dense)             (None, 10, 5642)          50778
# =================================================================
# Total params: 95,922
# Trainable params: 95,922
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.fit(X_b, y_b, nb_epoch=100)
# Out:
# /usr/local/lib/python3.5/dist-packages/keras/models.py:942: UserWarning: The `nb_epoch` argument in `fit` has been renamed `epochs`.
#   warnings.warn('The `nb_epoch` argument in `fit` '
# Epoch 1/100
# 1128/1128 [==============================] - 13s 11ms/step - loss: 8.6417 - acc: 0.0000e+00
# Epoch 2/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 8.6388 - acc: 3.5461e-04
# Epoch 3/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 8.6370 - acc: 8.8652e-05
# Epoch 4/100
# 1128/1128 [==============================] - 11s 10ms/step - loss: 8.6333 - acc: 7.9787e-04
# Epoch 5/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 8.6282 - acc: 7.0922e-04
# Epoch 6/100
# 1128/1128 [==============================] - 11s 10ms/step - loss: 8.6209 - acc: 0.0014
# Epoch 7/100
# 1128/1128 [==============================] - 11s 10ms/step - loss: 8.6112 - acc: 8.8652e-04
# Epoch 8/100
# 1128/1128 [==============================] - 11s 10ms/step - loss: 8.5988 - acc: 9.7518e-04
# Epoch 9/100
# 1128/1128 [==============================] - 11s 10ms/step - loss: 8.5831 - acc: 0.0014
# Epoch 10/100
# 1128/1128 [==============================] - 11s 10ms/step - loss: 8.5648 - acc: 0.0015
# Epoch 11/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.5436 - acc: 0.0014
# Epoch 12/100
# 1128/1128 [==============================] - 13s 11ms/step - loss: 8.5195 - acc: 0.0012
# Epoch 13/100
# 1128/1128 [==============================] - 11s 10ms/step - loss: 8.4929 - acc: 0.0017
# Epoch 14/100
# 1128/1128 [==============================] - 11s 10ms/step - loss: 8.4639 - acc: 0.0017
# Epoch 15/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 8.4328 - acc: 0.0018
# Epoch 16/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.3996 - acc: 0.0022
# Epoch 17/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.3646 - acc: 0.0027
# Epoch 18/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.3280 - acc: 0.0041
# Epoch 19/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.2899 - acc: 0.0043
# Epoch 20/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.2503 - acc: 0.0056
# Epoch 21/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.2096 - acc: 0.0058
# Epoch 22/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.1679 - acc: 0.0076
# Epoch 23/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.1253 - acc: 0.0094
# Epoch 24/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.0822 - acc: 0.0105
# Epoch 25/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 8.0375 - acc: 0.0129
# Epoch 26/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.9926 - acc: 0.0142
# Epoch 27/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.9469 - acc: 0.0164
# Epoch 28/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.9006 - acc: 0.0178
# Epoch 29/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 7.8537 - acc: 0.0191
# Epoch 30/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 7.8067 - acc: 0.0205
# Epoch 31/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 7.7594 - acc: 0.0217
# Epoch 32/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 7.7113 - acc: 0.0240
# Epoch 33/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 7.6633 - acc: 0.0243
# Epoch 34/100
# 1128/1128 [==============================] - 13s 11ms/step - loss: 7.6143 - acc: 0.0257
# Epoch 35/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.5661 - acc: 0.0264
# Epoch 36/100
# 1128/1128 [==============================] - 14s 12ms/step - loss: 7.5171 - acc: 0.0280
# Epoch 37/100
# 1128/1128 [==============================] - 14s 12ms/step - loss: 7.4678 - acc: 0.0290
# Epoch 38/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.4191 - acc: 0.0287
# Epoch 39/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.3703 - acc: 0.0309
# Epoch 40/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.3213 - acc: 0.0321
# Epoch 41/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.2723 - acc: 0.0319
# Epoch 42/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.2233 - acc: 0.0328
# Epoch 43/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 7.1750 - acc: 0.0355
# Epoch 44/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.1266 - acc: 0.0350
# Epoch 45/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 7.0780 - acc: 0.0363
# Epoch 46/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 7.0301 - acc: 0.0371
# Epoch 47/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.9825 - acc: 0.0372
# Epoch 48/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.9353 - acc: 0.0371
# Epoch 49/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.8881 - acc: 0.0395
# Epoch 50/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.8418 - acc: 0.0401
# Epoch 51/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.7952 - acc: 0.0411
# Epoch 52/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.7499 - acc: 0.0431
# Epoch 53/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.7049 - acc: 0.0425
# Epoch 54/100
# 1128/1128 [==============================] - 11s 10ms/step - loss: 6.6604 - acc: 0.0428
# Epoch 55/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.6166 - acc: 0.0449
# Epoch 56/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.5723 - acc: 0.0457
# Epoch 57/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.5295 - acc: 0.0478
# Epoch 58/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.4869 - acc: 0.0471
# Epoch 59/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 6.4449 - acc: 0.0487
# Epoch 60/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.4035 - acc: 0.0493
# Epoch 61/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 6.3624 - acc: 0.0529
# Epoch 62/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.3226 - acc: 0.0541
# Epoch 63/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.2827 - acc: 0.0546
# Epoch 64/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.2436 - acc: 0.0544
# Epoch 65/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 6.2053 - acc: 0.0578
# Epoch 66/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 6.1672 - acc: 0.0599
# Epoch 67/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 6.1305 - acc: 0.0598
# Epoch 68/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 6.0936 - acc: 0.0616
# Epoch 69/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 6.0572 - acc: 0.0631
# Epoch 70/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 6.0214 - acc: 0.0664
# Epoch 71/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.9868 - acc: 0.0662
# Epoch 72/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.9515 - acc: 0.0691
# Epoch 73/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.9179 - acc: 0.0687
# Epoch 74/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.8843 - acc: 0.0697
# Epoch 75/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.8516 - acc: 0.0741
# Epoch 76/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.8183 - acc: 0.0762
# Epoch 77/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.7869 - acc: 0.0782
# Epoch 78/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.7551 - acc: 0.0800
# Epoch 79/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.7238 - acc: 0.0855
# Epoch 80/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.6931 - acc: 0.0854
# Epoch 81/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.6631 - acc: 0.0888
# Epoch 82/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.6328 - acc: 0.0905
# Epoch 83/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.6032 - acc: 0.0934
# Epoch 84/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 5.5748 - acc: 0.0964
# Epoch 85/100
# 1128/1128 [==============================] - 12s 10ms/step - loss: 5.5459 - acc: 0.0985
# Epoch 86/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.5181 - acc: 0.1012
# Epoch 87/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.4905 - acc: 0.1045
# Epoch 88/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.4631 - acc: 0.1071
# Epoch 89/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.4355 - acc: 0.1123
# Epoch 90/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.4088 - acc: 0.1150
# Epoch 91/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.3823 - acc: 0.1182
# Epoch 92/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.3568 - acc: 0.1220
# Epoch 93/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.3312 - acc: 0.1250
# Epoch 94/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.3057 - acc: 0.1297
# Epoch 95/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.2803 - acc: 0.1317
# Epoch 96/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.2559 - acc: 0.1339
# Epoch 97/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.2310 - acc: 0.1368
# Epoch 98/100
# 1128/1128 [==============================] - 12s 11ms/step - loss: 5.2069 - acc: 0.1367
# Epoch 99/100
# 1128/1128 [==============================] - 13s 11ms/step - loss: 5.1823 - acc: 0.1429
# Epoch 100/100
# 1128/1128 [==============================] - 15s 13ms/step - loss: 5.1591 - acc: 0.1434

# %%
encoding = model.layers[0].get_weights()[0]

# %%
encoding.shape
# Out:
# (5642, 8)

# %%
def closest_word_to_vector(word_vector, num_nearby):
    distances = np.linalg.norm(encoding - word_vector, axis=1)
    closest = np.argsort(distances)[:num_nearby]
    return [index_to_word[i] for i in closest]

def closest_word(word, num_nearby):
    ind = word_to_index[word]
    word_vector = encoding[ind]
    return closest_word_to_vector(word_vector, num_nearby)

closest_word('currency', 6)
# Out:
# ['currency', 'beoh', 'intro', 'stride', 'needin', 'liftin']

# %%
def x_is_to_y_as_z_is_to(x, y, z, num_closest):
    x_v = encoding[word_to_index[x]]
    y_v = encoding[word_to_index[y]]
    z_v = encoding[word_to_index[z]]
    
    relationship_vector = x_v - y_v
    z_is_to = z_v + relationship_vector
    
    return closest_word_to_vector(z_is_to, num_closest)

x_is_to_y_as_z_is_to("big", "rings", "america", 5)
# Out:
# ['gain', 'riri', 'runaway', 'purposeand', 'reason']

# %%
prediction_model = Sequential()
prediction_model.add(Dense(encoding_size, input_dim=vocab_n + 1, activation='relu'))
prediction_model.add(Dense(vocab_n + 1, activation='softmax'))

prediction_model.compile(optimizer=Adam(), loss='categorical_crossentropy', metrics=['accuracy'])

prediction_model.set_weights(model.get_weights())

def words_likely_to_be_in_the_context_of(word, num_context):
    input_vector = np.zeros((1, vocab_n + 1))
    input_vector[0, word_to_index[word]] = 1
    output_vector = prediction_model.predict(input_vector)[0]
    top_context = np.argsort(-output_vector)[:num_context]
    return [index_to_word[i] for i in top_context]

words_likely_to_be_in_the_context_of('america', 10)
# Out:
# ['weighed',
#  'cyborg',
#  'neighbors',
#  'sides',
#  'proud',
#  'should',
#  'idols',
#  'karma',
#  'answer',
#  'lavish']

# %%
def cosine_similarity(u, v):
    
    distance = 0.0
    dot = np.dot(u, v)
    norm_u = np.linalg.norm(u)
    
    norm_v = np.linalg.norm(v)
    cosine_similarity = dot / (norm_u * norm_v)
    
    return cosine_similarity

# %%
cosine_similarity(encoding[word_to_index['school']], encoding[word_to_index['ignore']])
# Out:
# 0.3816335

# %% [markdown]
# ## Attempting TSNE

# %%
import numpy as np
from sklearn.manifold import TSNE

X_embedded = TSNE(n_components=2, perplexity=100).fit_transform(encoding)
X_embedded.shape
# Out:
# (5642, 2)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(50, 25))

for i in range(0, len(X_embedded)):
    plt.scatter(X_embedded[i, 0], X_embedded[i, 1], s=50)
    
    if (i % 20 == 0):
        plt.annotate(
            index_to_word[i], 
            (
                X_embedded[i, 0], 
                X_embedded[i, 1]
            ), 
            bbox=dict(boxstyle="round", 
                      fc=(1.0, 0.7, 0.7),
                      ec=(1., .5, .5)), 
            fontsize=15
        )
        

plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(50, 25))

for i in range(0, len(X_embedded)):
    plt.scatter(X_embedded[i, 0], X_embedded[i, 1], s=50)
    
    if (i % 20 == 0):
        plt.annotate(
            index_to_word[i], 
            (
                X_embedded[i, 0], 
                X_embedded[i, 1]
            ), 
            bbox=dict(boxstyle="round", 
                      fc=(1.0, 0.7, 0.7),
                      ec=(1., .5, .5)), 
            fontsize=15
        )
        

plt.show()

# %%
import matplotlib.pyplot as plt

words_of_interest = [
    'drake', 
    'toronto', 
    'quavo', 
    'bitches', 
    'sex', 
    'kill', 
    'murder', 
    'phone', 
    'blackberry', 
    'beer', 
    'liquor', 
    'vodka',
    'batphone',
    'done',
    'memories',
    'inspired',
    'summary',
    'grammy',
    'iphone',
    'emmys',
    'currency',
    'dollar',
    'dollars',
    'euro'
]

plt.figure(figsize=(20, 10))

for i in range(0, len(X_embedded)):
    plt.scatter(X_embedded[i, 0], X_embedded[i, 1], s=50)
    
    if (index_to_word[i] in words_of_interest):
        plt.annotate(
            index_to_word[i], 
            (
                X_embedded[i, 0], 
                X_embedded[i, 1]
            ), 
            bbox=dict(boxstyle="round", 
                      fc=(1.0, 0.7, 0.7),
                      ec=(1., .5, .5)), 
            fontsize=15
        )
        

plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-147-1b4f84d9670b> in <module>()
#      29     plt.scatter(X_embedded[i, 0], X_embedded[i, 1], s=50)
#      30
# ---> 31     if (index_to_word[i] in words_of_interest):
#      32         plt.annotate(
#      33             index_to_word[i],
#
# KeyError: 5641
